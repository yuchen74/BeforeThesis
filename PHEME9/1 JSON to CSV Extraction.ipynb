# %%
import os
import numpy as np
import pandas as pd
import json
import csv

# %%
path_to_json = r'D:\論文\PHEME9\Data\gurlitt/'
folders = [pos_json for pos_json in os.listdir(path_to_json) ]
base = r'D:\論文\PHEME9\Data\gurlitt'
# to display full text
pd.set_option('display.max_colwidth', -1)
# Out:
# <ipython-input-38-15e21a2e2195>:5: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)

# %%
#within_tweetfolders = [pos for pos in os.listdir(r'D:\論文\PHEME9\Data\sydneysiege\rumours\544268186292867072')]

# %%
for folder in folders:
    
    if (folder == 'non-rumours' or folder == 'rumours'):
            within_tweetid = os.path.join(base, folder)
            #print(within_tweetid)
            within_folders = [pos for pos in os.listdir(within_tweetid)]
            #print(within_folders)
            for file in within_folders:
                if not file.startswith('.'):
                    
                    src_df = []
                    within_tweetfolder = os.path.join(base, folder, file)
                    #print (within_tweetfolder)

                    src_tweet = []
                    for pos in os.listdir(within_tweetfolder):
                        if not pos.startswith('.') | pos.endswith('.json'):
                            src_tweet.append(pos)
                    
                    #print(each_tweet)
                    if src_tweet[1] == 'source-tweets':
                        source = os.path.join(base, folder, file, within_tweetfolder,'source-tweets')
                        #print(source)
                        tweets = [pos for pos in os.listdir(source)]
                        #print(tweets)
                        for tweet in tweets:
                            if not tweet.startswith('.'):
                                
                                ids = os.path.join(base, folder, file, within_tweetfolder, 'source-tweets', tweet)
                                if ids.endswith('.json'):
                                    data = []
                                    #print(ids)
                                    with open(ids,'r') as f:
                                        src_json = json.load(f)
                                    src_df = pd.DataFrame(src_json)
                                    #extracting mentions id

                                    #extracting user's info
                                    usr_prop1 = src_df.user.id
                                    #make new datframe by taking only few attributes from original src_df
                                    src_df = src_df[['id','text', 'created_at' ]]
                                    src_df['user_id'] = usr_prop1

                                    #reset index of dataframe
                                    src_df = src_df.reset_index()
                                    src_df.drop(['index'], axis = 1, inplace = True)
                                    src_df = src_df.iloc[0,:]
                                    src_df = src_df.reset_index()
                                    src_df.drop("index", axis = 1, inplace = True)

                                    #adding row by row data in csv
                                    data.append(src_df.iloc[0,0])
                                    data.append(src_df.iloc[3,0])
                                    data.append(src_df.iloc[1,0])
                                    data.append(src_df.iloc[2,0])



                    if src_tweet[0] == 'reactions':
                        reactions = os.path.join(base, folder, file, within_tweetfolder,'reactions')
                        tweets_reactions = [pos for pos in os.listdir(reactions)]
                        for tweet_reaction in tweets_reactions:
                            if not tweet_reaction.startswith('.'):
                                mix_data = []
                                mix_data.extend(data)
                                ids_reactions = os.path.join(base, folder, file, within_tweetfolder, 'reactions', tweet_reaction)
                                if ids_reactions.endswith('.json'):
                                    data_reactions = []
                                    with open(ids_reactions,'r') as f:
                                        reactions_json = json.load(f)
                                    reactions_df = pd.DataFrame(reactions_json)
                                     #extracting mentions id

                                    #extracting user's info
                                    reply_usr_prop1 = reactions_df.user.id
                                    reactions_df = reactions_df[['id','text', 'created_at']]
                                    reactions_df['user_id'] = reply_usr_prop1


                                    reactions_df = reactions_df.reset_index()
                                    reactions_df.drop(['index'], axis = 1, inplace = True)
                                    reactions_df = reactions_df.iloc[0,:]
                                    reactions_df = reactions_df.reset_index()
                                    reactions_df.drop("index", axis = 1, inplace = True)
                                    data_reactions.append(reactions_df.iloc[0,0])
                                    data_reactions.append(reactions_df.iloc[3,0])
                                    data_reactions.append(reactions_df.iloc[1,0])
                                    data_reactions.append(reactions_df.iloc[2,0])


                                    mix_data.extend(data_reactions)
                                    #assign labels
                                    if (folder == 'non-rumours'):
                                        mix_data.append(0)
                                    elif (folder == 'rumours'):
                                        mix_data.append(1)
                                    #data_reactions.append(0)
                                    with open(r'D:\論文\PHEME9\Data\CSV\gurlitt.csv', 'a',newline = '', encoding = 'utf-8') as csvFile:
                                        writer = csv.writer(csvFile)
                                        writer.writerow(mix_data)
                                    csvFile.close()

# %%
exact_data = pd.read_csv(r'D:\論文\PHEME9\Data\CSV\gurlitt.csv', encoding = 'utf-8', header = None)

# %%
exact_data.head()
# Out:
#                     0         1  \
# 0  535450182142672897  21397917
# 1  535450182142672897  21397917
# 2  535450182142672897  21397917
# 3  535450182142672897  21397917
# 4  535450705134649345  38681183
#
#                                                                                                                                               2  \
# 0  Former top judge thinks #Nazi-stolen art 'belongs in a museum' #indianajones #Gurlitt #Germany http://t.co/kqyjtGun9r http://t.co/xNxGpg7RAQ
# 1  Former top judge thinks #Nazi-stolen art 'belongs in a museum' #indianajones #Gurlitt #Germany http://t.co/kqyjtGun9r http://t.co/xNxGpg7RAQ
# 2  Former top judge thinks #Nazi-stolen art 'belongs in a museum' #indianajones #Gurlitt #Germany http://t.co/kqyjtGun9r http://t.co/xNxGpg7RAQ
# 3  Former top judge thinks #Nazi-stolen art 'belongs in a museum' #indianajones #Gurlitt #Germany http://t.co/kqyjtGun9r http://t.co/xNxGpg7RAQ
# 4  German, Swiss handling of Gurlitt hoard and bequest is all wrong, says senior Austrian curator http://t.co/4Ioh8t2GfS http://t.co/diZjKe0gN6
#
#                                 3                   4          5  \
# 0  Thu Nov 20 15:10:46 +0000 2014  535451147931512833  383743288
# 1  Thu Nov 20 15:10:46 +0000 2014  535451150859132928  20003443
# 2  Thu Nov 20 15:10:46 +0000 2014  535451364818964481  195699945
# 3  Thu Nov 20 15:10:46 +0000 2014  535452154262474752  20003443
# 4  Thu Nov 20 15:12:50 +0000 2014  535451540589641728  383743288
#
#                                                                                                                                       6  \
# 0  @TheLocalGermany Very good article. Watch our film @vimeo and find out how complicated this is though. https://t.co/0ZmvC5x4Bg
# 1  @TheLocalGermany Museums great for burying things for "experts" to gloat over. State funded collector's.
# 2  @wiganshale er... whereas private collectors let people in to have a gander any time they want?
# 3  @tombarfield true but at least I don't pay for their pleasure. As a philistine, I prefer a nice photo  to half a cow in formaldehyde
# 4  @TheArtNewspaper check our Film https://t.co/0ZmvC5x4Bg
#
#                                 7  8
# 0  Thu Nov 20 15:14:36 +0000 2014  0
# 1  Thu Nov 20 15:14:37 +0000 2014  0
# 2  Thu Nov 20 15:15:28 +0000 2014  0
# 3  Thu Nov 20 15:18:36 +0000 2014  0
# 4  Thu Nov 20 15:16:10 +0000 2014  0

# %%
exact_data.shape
# Out:
# (41, 9)
